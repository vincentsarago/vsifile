# %%
import rasterio
from rio_tiler.io import Reader
from vsifile import VSIFile

import logging

logging.basicConfig(level=logging.DEBUG)

# %%
with rasterio.open(
    "tests/fixtures/cog.tif",
    opener=VSIFile,
) as src:
    with Reader(None, dataset=src) as dst:
        _ = dst.info()
# Out:
# DEBUG:rasterio.env:Entering env context: <rasterio.env.Env object at 0x1754d7b20>
# DEBUG:rasterio.env:Starting outermost env
# DEBUG:rasterio.env:No GDAL environment exists
# DEBUG:rasterio.env:New GDAL environment <rasterio._env.GDALEnv object at 0x1073b1a90> created
# DEBUG:rasterio._env:GDAL_DATA found in environment.
# DEBUG:rasterio._env:PROJ_LIB found in environment.
# DEBUG:rasterio._env:Started GDALEnv: self=<rasterio._env.GDALEnv object at 0x1073b1a90>.
# DEBUG:rasterio.env:Entered env context: <rasterio.env.Env object at 0x1754d7b20>
# DEBUG:rasterio._base:Sharing flag: 0
# DEBUG:rasterio._base:Args: filename='/vsipyopener/tests/fixtures/cog.tif', flags=66
# DEBUG:rasterio._vsiopener:Looking up opener: registry={'tests/fixtures/cog.tif': <function VSIFile at 0x175019430>}, filename='tests/fixtures/cog.tif'
# DEBUG:vsifile:Using /tmp/visfile-cache Cache directory
# DEBUG:rasterio._vsiopener:Opened file object: file_obj=FileReader(tests/fixtures/cog.tif), mode='rb'
# DEBUG:vsifile:Opening: tests/fixtures/cog.tif (mode: rb)
# DEBUG:vsifile:Adding Header in cache
# DEBUG:vsifile:Fetching 0->32768
# DEBUG:vsifile:Fetching 0->60000
# DEBUG:rasterio._base:Nodata success: 0, Nodata value: 0.000000
# DEBUG:rasterio._base:Dataset <open DatasetReader name='/vsipyopener/tests/fixtures/cog.tif' mode='r'> is started.
# DEBUG:rasterio.env:Exiting env context: <rasterio.env.Env object at 0x1754d7b20>
# DEBUG:rasterio.env:Cleared existing <rasterio._env.GDALEnv object at 0x1073b1a90> options
# DEBUG:rasterio._env:Stopped GDALEnv <rasterio._env.GDALEnv object at 0x1073b1a90>.
# DEBUG:rasterio.env:Exiting outermost env
# DEBUG:rasterio.env:Exited env context: <rasterio.env.Env object at 0x1754d7b20>
# DEBUG:rasterio.env:Entering env context: <rasterio.env.Env object at 0x1073b1a90>
# DEBUG:rasterio.env:Starting outermost env
# DEBUG:rasterio.env:No GDAL environment exists
# DEBUG:rasterio.env:New GDAL environment <rasterio._env.GDALEnv object at 0x1754d75e0> created
# DEBUG:rasterio._env:GDAL_DATA found in environment.
# DEBUG:rasterio._env:PROJ_LIB found in environment.
# DEBUG:rasterio._env:Started GDALEnv: self=<rasterio._env.GDALEnv object at 0x1754d75e0>.
# DEBUG:rasterio.env:Entered env context: <rasterio.env.Env object at 0x1073b1a90>
# DEBUG:rasterio.crs:Matched. confidence=100, c_code=b'32621', c_name=b'EPSG'
# DEBUG:rasterio._base:Args: filename='<VRTDataset rasterYSize="2667" rasterXSize="2658"><VRTRasterBand /><SRS>PROJCS["WGS 84 / UTM zone 21N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-57],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32621"]]</SRS><GeoTransform>373185.0,100.01126757344892,0.0,8286015.0,0.0,-100.01126757344908</GeoTransform></VRTDataset>', flags=6
# DEBUG:rasterio._warp:Created exact transformer
# DEBUG:rasterio._base:Args: filename='<VRTDataset rasterYSize="2667" rasterXSize="2658"><VRTRasterBand /><SRS>PROJCS["WGS 84 / UTM zone 21N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-57],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32621"]]</SRS><GeoTransform>373185.0,100.01126757344892,0.0,8286015.0,0.0,-100.01126757344908</GeoTransform></VRTDataset>', flags=6
# DEBUG:rasterio._warp:Created exact transformer
# DEBUG:rasterio._vsiopener:Closing: file_obj=FileReader(tests/fixtures/cog.tif)
# DEBUG:rasterio.env:Exiting env context: <rasterio.env.Env object at 0x1073b1a90>
# DEBUG:rasterio.env:Cleared existing <rasterio._env.GDALEnv object at 0x1754d75e0> options
# DEBUG:rasterio._env:Stopped GDALEnv <rasterio._env.GDALEnv object at 0x1754d75e0>.
# DEBUG:rasterio.env:Exiting outermost env
# DEBUG:rasterio.env:Exited env context: <rasterio.env.Env object at 0x1073b1a90>

# %%
with rasterio.open(
    "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/15/T/VK/2023/10/S2B_15TVK_20231008_0_L2A/TCI.tif",
    opener=VSIFile,
) as src:
    with Reader(None, dataset=src) as dst:
        _ = dst.info()
# Out:
# DEBUG:botocore.hooks:Changing event name from creating-client-class.iot-data to creating-client-class.iot-data-plane
# DEBUG:botocore.hooks:Changing event name from before-call.apigateway to before-call.api-gateway
# DEBUG:botocore.hooks:Changing event name from request-created.machinelearning.Predict to request-created.machine-learning.Predict
# DEBUG:botocore.hooks:Changing event name from before-parameter-build.autoscaling.CreateLaunchConfiguration to before-parameter-build.auto-scaling.CreateLaunchConfiguration
# DEBUG:botocore.hooks:Changing event name from before-parameter-build.route53 to before-parameter-build.route-53
# DEBUG:botocore.hooks:Changing event name from request-created.cloudsearchdomain.Search to request-created.cloudsearch-domain.Search
# DEBUG:botocore.hooks:Changing event name from docs.*.autoscaling.CreateLaunchConfiguration.complete-section to docs.*.auto-scaling.CreateLaunchConfiguration.complete-section
# DEBUG:botocore.hooks:Changing event name from before-parameter-build.logs.CreateExportTask to before-parameter-build.cloudwatch-logs.CreateExportTask
# DEBUG:botocore.hooks:Changing event name from docs.*.logs.CreateExportTask.complete-section to docs.*.cloudwatch-logs.CreateExportTask.complete-section
# DEBUG:botocore.hooks:Changing event name from before-parameter-build.cloudsearchdomain.Search to before-parameter-build.cloudsearch-domain.Search
# DEBUG:botocore.hooks:Changing event name from docs.*.cloudsearchdomain.Search.complete-section to docs.*.cloudsearch-domain.Search.complete-section
# DEBUG:botocore.utils:IMDS ENDPOINT: http://169.254.169.254/
# DEBUG:botocore.credentials:Looking for credentials via: env
# DEBUG:botocore.credentials:Looking for credentials via: assume-role
# DEBUG:botocore.credentials:Looking for credentials via: assume-role-with-web-identity
# DEBUG:botocore.credentials:Looking for credentials via: sso
# DEBUG:botocore.credentials:Looking for credentials via: shared-credentials-file
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# DEBUG:rasterio.env:Entering env context: <rasterio.env.Env object at 0x17571e910>
# DEBUG:rasterio.env:Starting outermost env
# DEBUG:rasterio.env:No GDAL environment exists
# DEBUG:rasterio.env:New GDAL environment <rasterio._env.GDALEnv object at 0x17571e760> created
# DEBUG:rasterio._env:GDAL_DATA found in environment.
# DEBUG:rasterio._env:PROJ_LIB found in environment.
# DEBUG:rasterio._env:Started GDALEnv: self=<rasterio._env.GDALEnv object at 0x17571e760>.
# DEBUG:rasterio.env:Entered env context: <rasterio.env.Env object at 0x17571e910>
# DEBUG:rasterio._base:Sharing flag: 0
# DEBUG:rasterio._base:Args: filename='/vsipyopener/https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/15/T/VK/2023/10/S2B_15TVK_20231008_0_L2A/TCI.tif', flags=66
# DEBUG:rasterio._vsiopener:Looking up opener: registry={'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/15/T/VK/2023/10/S2B_15TVK_20231008_0_L2A/TCI.tif': <function VSIFile at 0x175019430>}, filename='https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/15/T/VK/2023/10/S2B_15TVK_20231008_0_L2A/TCI.tif'
# DEBUG:vsifile:Using /tmp/visfile-cache Cache directory
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/vincentsarago/Dev/venv/py39/lib/python3.9/site-packages/certifi/cacert.pem'
# DEBUG:rasterio._vsiopener:Opened file object: file_obj=HttpReader(https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/15/T/VK/2023/10/S2B_15TVK_20231008_0_L2A/TCI.tif), mode='rb'
# DEBUG:vsifile:Opening: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/15/T/VK/2023/10/S2B_15TVK_20231008_0_L2A/TCI.tif (mode: rb)
# DEBUG:httpcore.connection:connect_tcp.started host='sentinel-cogs.s3.us-west-2.amazonaws.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x17571e6d0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x1755eacc0> server_hostname='sentinel-cogs.s3.us-west-2.amazonaws.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x175736820>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'x-amz-id-2', b'E4wEtAxilAmU2id/0AvR9Ifn/Bh43niGbkYRXssTVeXbotLHh56T6qYT32dkOvoFzgrcW0Kq0p8='), (b'x-amz-request-id', b'CPJGG3X8JY8NGQPY'), (b'Date', b'Mon, 13 Nov 2023 10:34:55 GMT'), (b'Last-Modified', b'Mon, 09 Oct 2023 01:23:09 GMT'), (b'ETag', b'"3e23880cd7ac8a32ae71c55ad4f85c5d-24"'), (b'x-amz-server-side-encryption', b'AES256'), (b'Cache-Control', b'public, max-age=31536000, immutable'), (b'Accept-Ranges', b'bytes'), (b'Content-Type', b'image/tiff; application=geotiff; profile=cloud-optimized'), (b'Server', b'AmazonS3'), (b'Content-Length', b'200959614')])
# INFO:httpx:HTTP Request: HEAD https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/15/T/VK/2023/10/S2B_15TVK_20231008_0_L2A/TCI.tif "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'HEAD']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:vsifile:Adding Header in cache
# DEBUG:vsifile:Fetching 0->32768
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 206, b'Partial Content', [(b'x-amz-id-2', b'PLz+nziQGVcc/YQeh9PfYE8v1Vfwu2gfY0FnXuEQug3vIPRN2VzCGgzOGw2QVYGHe57mIupzABA='), (b'x-amz-request-id', b'EFMMZCR5DRHCBBJH'), (b'Date', b'Mon, 13 Nov 2023 10:34:56 GMT'), (b'Last-Modified', b'Mon, 09 Oct 2023 01:23:09 GMT'), (b'ETag', b'"3e23880cd7ac8a32ae71c55ad4f85c5d-24"'), (b'x-amz-server-side-encryption', b'AES256'), (b'Cache-Control', b'public, max-age=31536000, immutable'), (b'Accept-Ranges', b'bytes'), (b'Content-Range', b'bytes 0-32767/200959614'), (b'Content-Type', b'image/tiff; application=geotiff; profile=cloud-optimized'), (b'Server', b'AmazonS3'), (b'Content-Length', b'32768')])
# INFO:httpx:HTTP Request: GET https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/15/T/VK/2023/10/S2B_15TVK_20231008_0_L2A/TCI.tif "HTTP/1.1 206 Partial Content"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:vsifile:Fetching 0->60000
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 206, b'Partial Content', [(b'x-amz-id-2', b'VXpeZ58xGZIG7SXi8Xi750dOM59hvL4sEP7u6NtVYZtill5jd6gnjGV2c7CFeH8VVR20KVrhzVE='), (b'x-amz-request-id', b'EFMTWBGBZ9W4G8ZV'), (b'Date', b'Mon, 13 Nov 2023 10:34:56 GMT'), (b'Last-Modified', b'Mon, 09 Oct 2023 01:23:09 GMT'), (b'ETag', b'"3e23880cd7ac8a32ae71c55ad4f85c5d-24"'), (b'x-amz-server-side-encryption', b'AES256'), (b'Cache-Control', b'public, max-age=31536000, immutable'), (b'Accept-Ranges', b'bytes'), (b'Content-Range', b'bytes 0-59999/200959614'), (b'Content-Type', b'image/tiff; application=geotiff; profile=cloud-optimized'), (b'Server', b'AmazonS3'), (b'Content-Length', b'60000')])
# INFO:httpx:HTTP Request: GET https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/15/T/VK/2023/10/S2B_15TVK_20231008_0_L2A/TCI.tif "HTTP/1.1 206 Partial Content"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:rasterio._base:Nodata success: 1, Nodata value: 0.000000
# DEBUG:rasterio._base:Nodata success: 1, Nodata value: 0.000000
# DEBUG:rasterio._base:Nodata success: 1, Nodata value: 0.000000
# DEBUG:rasterio._base:Dataset <open DatasetReader name='/vsipyopener/https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/15/T/VK/2023/10/S2B_15TVK_20231008_0_L2A/TCI.tif' mode='r'> is started.
# DEBUG:rasterio.env:Exiting env context: <rasterio.env.Env object at 0x17571e910>
# DEBUG:rasterio.env:Cleared existing <rasterio._env.GDALEnv object at 0x17571e760> options
# DEBUG:rasterio._env:Stopped GDALEnv <rasterio._env.GDALEnv object at 0x17571e760>.
# DEBUG:rasterio.env:Exiting outermost env
# DEBUG:rasterio.env:Exited env context: <rasterio.env.Env object at 0x17571e910>
# DEBUG:rasterio.env:Entering env context: <rasterio.env.Env object at 0x1754d72b0>
# DEBUG:rasterio.env:Starting outermost env
# DEBUG:rasterio.env:No GDAL environment exists
# DEBUG:rasterio.env:New GDAL environment <rasterio._env.GDALEnv object at 0x17573bb80> created
# DEBUG:rasterio._env:GDAL_DATA found in environment.
# DEBUG:rasterio._env:PROJ_LIB found in environment.
# DEBUG:rasterio._env:Started GDALEnv: self=<rasterio._env.GDALEnv object at 0x17573bb80>.
# DEBUG:rasterio.env:Entered env context: <rasterio.env.Env object at 0x1754d72b0>
# DEBUG:rasterio.crs:Matched. confidence=100, c_code=b'32615', c_name=b'EPSG'
# DEBUG:rasterio._base:Args: filename='<VRTDataset rasterYSize="10980" rasterXSize="10980"><VRTRasterBand /><SRS>PROJCS["WGS 84 / UTM zone 15N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-93],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32615"]]</SRS><GeoTransform>399960.0,10.0,0.0,5000040.0,0.0,-10.0</GeoTransform></VRTDataset>', flags=6
# DEBUG:rasterio._warp:Created exact transformer
# DEBUG:rasterio._base:Args: filename='<VRTDataset rasterYSize="10980" rasterXSize="10980"><VRTRasterBand /><SRS>PROJCS["WGS 84 / UTM zone 15N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-93],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32615"]]</SRS><GeoTransform>399960.0,10.0,0.0,5000040.0,0.0,-10.0</GeoTransform></VRTDataset>', flags=6
# DEBUG:rasterio._warp:Created exact transformer
# DEBUG:rasterio._vsiopener:Closing: file_obj=HttpReader(https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/15/T/VK/2023/10/S2B_15TVK_20231008_0_L2A/TCI.tif)
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:rasterio.env:Exiting env context: <rasterio.env.Env object at 0x1754d72b0>
# DEBUG:rasterio.env:Cleared existing <rasterio._env.GDALEnv object at 0x17573bb80> options
# DEBUG:rasterio._env:Stopped GDALEnv <rasterio._env.GDALEnv object at 0x17573bb80>.
# DEBUG:rasterio.env:Exiting outermost env
# DEBUG:rasterio.env:Exited env context: <rasterio.env.Env object at 0x1754d72b0>

# %%
with rasterio.open(
    "tests/fixtures/cog.tif",
    opener=VSIFile,
) as src:
    with Reader(None, dataset=src) as dst:
        _ = dst.preview()
# Out:
# DEBUG:rasterio.env:Entering env context: <rasterio.env.Env object at 0x1754d7ee0>
# DEBUG:rasterio.env:Starting outermost env
# DEBUG:rasterio.env:No GDAL environment exists
# DEBUG:rasterio.env:New GDAL environment <rasterio._env.GDALEnv object at 0x17507e220> created
# DEBUG:rasterio._env:GDAL_DATA found in environment.
# DEBUG:rasterio._env:PROJ_LIB found in environment.
# DEBUG:rasterio._env:Started GDALEnv: self=<rasterio._env.GDALEnv object at 0x17507e220>.
# DEBUG:rasterio.env:Entered env context: <rasterio.env.Env object at 0x1754d7ee0>
# DEBUG:rasterio._base:Sharing flag: 0
# DEBUG:rasterio._base:Args: filename='/vsipyopener/tests/fixtures/cog.tif', flags=66
# DEBUG:rasterio._vsiopener:Looking up opener: registry={'tests/fixtures/cog.tif': <function VSIFile at 0x175019430>}, filename='tests/fixtures/cog.tif'
# DEBUG:vsifile:Using /tmp/visfile-cache Cache directory
# DEBUG:rasterio._vsiopener:Opened file object: file_obj=FileReader(tests/fixtures/cog.tif), mode='rb'
# DEBUG:vsifile:Opening: tests/fixtures/cog.tif (mode: rb)
# DEBUG:rasterio._base:Nodata success: 0, Nodata value: 0.000000
# DEBUG:rasterio._base:Dataset <open DatasetReader name='/vsipyopener/tests/fixtures/cog.tif' mode='r'> is started.
# DEBUG:rasterio.env:Exiting env context: <rasterio.env.Env object at 0x1754d7ee0>
# DEBUG:rasterio.env:Cleared existing <rasterio._env.GDALEnv object at 0x17507e220> options
# DEBUG:rasterio._env:Stopped GDALEnv <rasterio._env.GDALEnv object at 0x17507e220>.
# DEBUG:rasterio.env:Exiting outermost env
# DEBUG:rasterio.env:Exited env context: <rasterio.env.Env object at 0x1754d7ee0>
# DEBUG:rasterio.env:Entering env context: <rasterio.env.Env object at 0x17507e220>
# DEBUG:rasterio.env:Starting outermost env
# DEBUG:rasterio.env:No GDAL environment exists
# DEBUG:rasterio.env:New GDAL environment <rasterio._env.GDALEnv object at 0x17572ddc0> created
# DEBUG:rasterio._env:GDAL_DATA found in environment.
# DEBUG:rasterio._env:PROJ_LIB found in environment.
# DEBUG:rasterio._env:Started GDALEnv: self=<rasterio._env.GDALEnv object at 0x17572ddc0>.
# DEBUG:rasterio.env:Entered env context: <rasterio.env.Env object at 0x17507e220>
# DEBUG:rasterio.crs:Matched. confidence=100, c_code=b'32621', c_name=b'EPSG'
# DEBUG:rasterio._io:Output nodata value read from file: None
# DEBUG:rasterio._io:Output nodata values: [None]
# DEBUG:rasterio._io:all_valid: True
# DEBUG:rasterio._io:mask_flags: ([<MaskFlags.all_valid: 1>],)
# DEBUG:rasterio._io:Jump straight to _read()
# DEBUG:rasterio._io:Window: None
# DEBUG:rasterio._io:IO window xoff=0.0 yoff=0.0 width=2658.0 height=2667.0
# DEBUG:vsifile:Fetching 86991->264279
# DEBUG:rasterio._vsiopener:Closing: file_obj=FileReader(tests/fixtures/cog.tif)
# DEBUG:rasterio.env:Exiting env context: <rasterio.env.Env object at 0x17507e220>
# DEBUG:rasterio.env:Cleared existing <rasterio._env.GDALEnv object at 0x17572ddc0> options
# DEBUG:rasterio._env:Stopped GDALEnv <rasterio._env.GDALEnv object at 0x17572ddc0>.
# DEBUG:rasterio.env:Exiting outermost env
# DEBUG:rasterio.env:Exited env context: <rasterio.env.Env object at 0x17507e220>
